# %%
import pandas as pd
import random as rd
from tqdm import tqdm

# %%
kw_lst = pd.read_csv('./kw_lst/light_kw_list.csv')['검색어'].to_list()
kw_lst
# Out:
# ['케인',
#  '레알',
#  '손흥민',
#  '유로파',
#  '바르셀로나',
#  'UEFA',
#  '호날두',
#  '맨유',
#  '포체티노',
#  '네이마르',
#  '한국',
#  'EPL',
#  '맨시티',
#  '메시',
#  '오피셜',
#  '토트넘',
#  '감독',
#  '영입',
#  '음바페',
#  '홀란드',
#  '이적',
#  '류현진',
#  '야구',
#  '대표팀',
#  '우승',
#  '김민재',
#  '안타',
#  '투수',
#  '홈런',
#  'KIA']

# %%
df = pd.read_csv('./news.csv')
df
# Out:
#                       date                                         title
# 0      2018-01-01 00:00:00                레알  베일 현금    토트넘  케인  대형 딜 가능성  \
# 1      2018-01-01 00:00:00                  또 일낸 윤정환의 세레소  기어이  컵 더블  달성
# 2      2018-01-01 00:00:00                        일본에 또 이도류  제2의 오타니 등장
# 3      2018-01-01 00:00:00           1083억 사나이  반 다이크  리버풀 합류    우승 원한다
# 4      2018-01-01 00:00:00                   4년 보장 아닌 1년 계약  양현종에게 전화위복
# ...                    ...                                           ...
# 36230  2022-12-31 00:00:00   병역 기피 논란  석현준  드디어 입 열었다  소속팀서 안 놔줘  정말 오해
# 36231  2022-12-31 00:00:00                  바르사에서 5년 뛴 선수잖아   영입 선택 옳았어
# 36232  2022-12-31 00:00:00       위기의 남자  김동엽  박진만 감독은 대행 시절  쓰지 않겠다 고 했다
# 36233  2022-12-31 00:00:00          텐 하흐  이례적 발언 화제    레알 마드리드한테 정말 고맙다
# 36234  2022-12-31 00:00:00    해트트릭할 뻔  리버풀 영입각    멀티 자책골  레스터CB에 조롱댓글 폭발
#
#                                                  article  interested
# ...

# %%
while True:
    for raw in tqdm(range(len(df))):

        if ('토트넘' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('승리'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('영입' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('합류' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('연승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('손흥민' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('영입' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('관심'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('대체자' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('클럽레코드' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('계획' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('준비' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('류현진' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('계약'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('사이영상' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('제구' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('방어율' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('ERA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('등판' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            

        if ('오타니' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('이도류'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홈런' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('탈삼진' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('방어율' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('ERA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('FA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('관심'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('대체자' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('영입' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('월드컵' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('예선' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('무승부' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('커리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('득점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('트리플더블' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('롯데' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('영입' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('연승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1 
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('경질' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('신인' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('드래프트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('대표팀' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('메달' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            
        if ('국가대표' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('메달' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('T1' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('연승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('대승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('캐리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('워리어스' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('연승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('수상' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('발롱도르' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골든슈' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('올림픽' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('메달' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('아시안게임' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('메달' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1

        if ('다저스' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('연승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('황희찬' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('Son' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('오승환' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('계약'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('세이브' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홀드' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('구위' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('방어율' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('ERA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('복귀' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('이강인' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('DRX' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('우승'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('마음' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데프트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('쏘니' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
        
        if ('Sonny' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('케인' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('요리스' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('선방'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('푸이그' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('안타'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홈런' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('타점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('클루셉스키' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('모우라' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('NBA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('MVP' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('올스타' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('MLB' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('MVP' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('올스타' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('수상' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
            
        if ('이대호' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('안타'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홈런' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('타점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('한동희' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('안타'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홈런' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('타점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('김원중' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('활약'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홀드' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('세이브' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
        
        if ('WBC' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
        
        if ('호날두' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('레알 마드리드' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('승리'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('영입' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('합류' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('연승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('레알' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('승리'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('영입' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('합류' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('연승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('베일' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('음바페' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('베스트' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('김하성' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('안타'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홈런' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('타점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            
        if ('최지만' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('안타'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홈런' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('타점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('김민재' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('이적'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('무실점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('김연경' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
            
        if ('EPL' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
            
        if ('트레이드' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
        
        if ('맨유' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('거절'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('패배' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('연패' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('완패' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('분노' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
        
        if ('개막' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
            
        if ('김광현' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('계약'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('방어율' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('ERA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('등판' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('추신수' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('안타'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('홈런' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('타점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('레일리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('계약'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('제구' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('방어율' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('ERA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('등판' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('린드블럼' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('계약'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('제구' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('방어율' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('ERA' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('등판' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('르브론' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('득점' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('트리플더블' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('박항서' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('결승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('우승' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('베스트11' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
            
        if ('조현우' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('승리' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('폭행' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
            
        if ('기성용' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('득점'in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('골' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도움' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('이적' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('진출' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도전' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('데뷔' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('도장' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('한국' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('활약' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
            if ('1위' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.9):
                df.loc[raw,'interested'] = 1
                
        if ('드라마' in df.loc[raw,'title']) and (rd.uniform(0,1) < 0.8):
            df.loc[raw,'interested'] = 1
                
            
    print(len(df[df['interested']==1]))
            
    if len(df[df['interested']==1]) > 3750:
        break
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 36235/36235 [00:42<00:00, 845.37it/s]
# 3767

# %%
df[df['interested']==1]
# Out:
#                       date                                      title
# 2      2018-01-01 00:00:00                     일본에 또 이도류  제2의 오타니 등장   \
# 10     2018-01-01 00:00:00     손흥민  시장 가치 389억 기록    세계 131위 EPL 43위
# 21     2018-01-02 00:00:00                역대 가장 빠른 개막  2018년 최대 변수 예고
# 30     2018-01-02 00:00:00       전문가    손흥민 무기  한국 조 최하위  일본 조1위 16강
# 40     2018-01-03 00:00:00              요렌테 알리 골 토트넘  스완지에 승리  SON풀타임
# ...                    ...                                        ...
# 36175  2022-12-29 00:00:00             바이아웃 삭제 거부하고 떠난 김민재  맨유 이적 합의
# 36178  2022-12-29 00:00:00        철벽 수비수  김민재  세리에A 나폴리 넘어 EPL 맨유 가나
# 36181  2022-12-29 00:00:00   트레이드가 잘된 걸 수도  KIA 먼저 떠난 친구처럼 이제는 한승혁 차례
# 36211  2022-12-30 00:00:00           월드컵 3회 우승 부터  1천283골 까지 숫자로 본 펠레
# 36214  2022-12-30 00:00:00        샌디에이고  김하성 트레이드 하나 프렐러 단장  타 구단 문의
#
#                                                  article  interested
# ...

# %%
df.to_csv('./news.csv', index=False)
